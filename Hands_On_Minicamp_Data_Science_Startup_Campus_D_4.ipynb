# %% [markdown]
# ## Import the Packages

# %%
# As Always Import Package!
import numpy as np # powerfull package🔥
import pandas as pd #to do the data manipulation
import matplotlib.pyplot as plt # plot 📈
from sklearn.datasets import load_diabetes # load diabetes dataset
from sklearn.model_selection import train_test_split # Model Selection
from sklearn.linear_model import LinearRegression # Regression
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error, mean_absolute_percentage_error # Metrics
import math #Mathematical advanced formula

# %% [markdown]
# ## Regression

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# *   https://scikit-learn.org/stable/datasets/toy_dataset.html#diabetes-dataset
# *   https://www4.stat.ncsu.edu/~boos/var.select/diabetes.html

# %%
# Load the diabetes dataset
diabetes_X, diabetes_Y=load_diabetes(return_X_y=True)

# %%
# Print the dataset
diabetes_X
# Out:
# array([[ 0.03807591,  0.05068012,  0.06169621, ..., -0.00259226,
#          0.01990749, -0.01764613],
#        [-0.00188202, -0.04464164, -0.05147406, ..., -0.03949338,
#         -0.06833155, -0.09220405],
#        [ 0.08529891,  0.05068012,  0.04445121, ..., -0.00259226,
#          0.00286131, -0.02593034],
#        ...,
#        [ 0.04170844,  0.05068012, -0.01590626, ..., -0.01107952,
#         -0.04688253,  0.01549073],
#        [-0.04547248, -0.04464164,  0.03906215, ...,  0.02655962,
#          0.04452873, -0.02593034],
#        [-0.04547248, -0.04464164, -0.0730303 , ..., -0.03949338,
#         -0.00422151,  0.00306441]])

# %%
# Use only one feature
diabetes_X=diabetes_X[:,np.newaxis,2]
diabetes_X
# Out:
# array([[ 0.06169621],
#        [-0.05147406],
#        [ 0.04445121],
#        [-0.01159501],
#        [-0.03638469],
#        [-0.04069594],
#        [-0.04716281],
#        [-0.00189471],
#        [ 0.06169621],
#        [ 0.03906215],
#        [-0.08380842],
#        [ 0.01750591],
#        [-0.02884001],
#        [-0.00189471],
#        [-0.02560657],
#        [-0.01806189],
#        [ 0.04229559],
#        [ 0.01211685],
#        [-0.0105172 ],
#        [-0.01806189],
#        [-0.05686312],
#        [-0.02237314],
#        [-0.00405033],
#        [ 0.06061839],
#        [ 0.03582872],
#        [-0.01267283],
#        [-0.07734155],
#        [ 0.05954058],
#        [-0.02129532],
#        [-0.00620595],
#        [ 0.04445121],
#        [-0.06548562],
#        [ 0.12528712],
#        [-0.05039625],
#        [-0.06332999],
#        [-0.03099563],
#        [ 0.02289497],
#        [ 0.01103904],
#        [ 0.07139652],
#        [ 0.01427248],
#        [-0.00836158],
# ...

# %%
# Split the data
diabetes_X_train=diabetes_X[:-20]
diabetes_X_test=diabetes_X[-20:]

# %%
# Split the targets into training/testing sets
diabetes_Y_train=diabetes_Y[:-20]
diabetes_Y_test=diabetes_Y[-20:]

# %%
#Create the linear regression object
model=LinearRegression()

# %%
#Train the model
model.fit(diabetes_X_train, diabetes_Y_train)
# Out:
# LinearRegression()

# %%
diabetes_Y_pred=model.predict(diabetes_X_test)

# %%
#Model evaluation
#Mean Squared Error (MSE)
print("The MSE value is: %.2f" %mean_squared_error(diabetes_Y_test, diabetes_Y_pred))

#Root MSE (RMSE)
print("The RMSE value is: %.2f" %math.sqrt(mean_squared_error(diabetes_Y_test, diabetes_Y_pred)))
# semakin besar, semakin buruk

#Coefficient of Determination (R^2)
print("The R^2 value is: %.3f" %r2_score(diabetes_Y_test, diabetes_Y_pred)) 
# seberapa besar variabel y dipengaruhi oleh variabel x

#Mean Absolute Error (MAE)
print("The MAE value is: %.2f" %mean_absolute_error(diabetes_Y_test, diabetes_Y_pred))

#Mean Absolute Percentage Error (MAPE)
print("The MAPE value is: %.2f" %mean_absolute_percentage_error(diabetes_Y_test, diabetes_Y_pred))
# Out:
# The MSE value is: 2548.07
# The RMSE value is: 50.48
# The R^2 value is: 0.473
# The MAE value is: 41.23
# The MAPE value is: 0.49

# %%
#Slope and intercept

print(model.coef_)
print(model.intercept_)
# Out:
# [938.23786125]
# 152.91886182616113

# %%
a = model.coef_
b = model.intercept_
x = float(input('Input nilai BMI: '))
y = a*x+b

print(y)
# Out:
# Input nilai BMI: 13
# [12350.01105809]

# %%
#Plot Output
plt.scatter(diabetes_X_test,diabetes_Y_test,color='black')
plt.plot(diabetes_X_test, diabetes_Y_pred,color='red')
plt.show()
